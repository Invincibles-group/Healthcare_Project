# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
project = 'C:\St. Clair\Semester -3\Healthcare Analytics\dataset'

# %%
files = ['cms_hospital_patient_satisfaction_2016.csv',
         'cms_hospital_patient_satisfaction_2017.csv',
         'cms_hospital_patient_satisfaction_2018.csv',
         'cms_hospital_patient_satisfaction_2019.csv',
         'cms_hospital_patient_satisfaction_2020.csv']

# %%
dfs = []
for f in files:
    dfs.append(pd.read_csv(os.path.join(project, f)))

# %%
df1 = dfs[0]
df1.head()
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number     HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701         H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701      H_CLEAN_HSP_SN_P
# 3  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_U_P
# 4  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_LINEAR_SCORE
#
#                                      HCAHPS Question  ...  \
# ...

# %%
df1.notnull
# Out:
# <bound method DataFrame.notnull of         Facility ID                     Facility Name                 Address  \
# 0             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...             ...                               ...                     ...
# 264380       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264381       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264382       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264383       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264384       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
#
# ...

# %%
#df1.replace(np.nan, 0)

# %%
df1.dropna
# Out:
# <bound method DataFrame.dropna of         Facility ID                     Facility Name                 Address  \
# 0             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4             10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...             ...                               ...                     ...
# 264380       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264381       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264382       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264383       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
# 264384       670114             WEIMAR MEDICAL CENTER           400 YOUENS DR
#
# ...

# %%
df1['Efficient use of medical imaging national comparison footnote'] = df1['Efficient use of medical imaging national comparison footnote'].fillna(0)
df1['Timeliness of care national comparison footnote'] = df1['Timeliness of care national comparison footnote'].fillna(0)
df1['Effectiveness of care national comparison footnote'] = df1['Effectiveness of care national comparison footnote'].fillna(0)
df1['Patient experience national comparison footnote'] = df1['Patient experience national comparison footnote'].fillna(0)

# %%
df2= df1

# %%
df2.head()
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number     HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701         H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701      H_CLEAN_HSP_SN_P
# 3  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_U_P
# 4  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_LINEAR_SCORE
#
#                                      HCAHPS Question  ...  \
# ...

# %%
df2.isnull().sum()
# Out:
# Facility ID                                                           0
# Facility Name                                                         0
# Address                                                               0
# City                                                                  0
# State                                                                 0
# ZIP Code                                                              0
# County Name                                                         825
# Phone Number                                                          0
# HCAHPS Measure ID                                                     0
# HCAHPS Question                                                       0
# HCAHPS Answer Description                                             0
# Patient Survey Star Rating                                            0
# Patient Survey Star Rating Footnote                              248677
# ...

# %%
df2 = df2.replace(" ", np.NaN)
df2.head()
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number     HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701         H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701      H_CLEAN_HSP_SN_P
# 3  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_U_P
# 4  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_LINEAR_SCORE
#
#                                      HCAHPS Question  ...  \
# ...

# %%
df2.shape
# Out:
# (264385, 43)

# %%
df2['County Name'] = df2['County Name'].fillna(df2['County Name'].mode()[0])
df2['Patient Survey Star Rating Footnote'] = df2['Patient Survey Star Rating Footnote'].fillna(df2['Patient Survey Star Rating Footnote'].mode()[0])
df2['HCAHPS Answer Percent Footnote'] = df2['HCAHPS Answer Percent Footnote'].fillna(df2['HCAHPS Answer Percent Footnote'].mode()[0])
df2['Number of Completed Surveys Footnote'] = df2['Number of Completed Surveys Footnote'].fillna(df2['Number of Completed Surveys Footnote'].mode()[0])
df2['Survey Response Rate Percent Footnote'] = df2['Survey Response Rate Percent Footnote'].fillna(df2['Survey Response Rate Percent Footnote'].mode()[0])
df2['Meets criteria for promoting interoperability of EHRs'] = df2['Meets criteria for promoting interoperability of EHRs'].fillna(df2['Meets criteria for promoting interoperability of EHRs'].mode()[0])
df2['Hospital overall rating footnote'] = df2['Hospital overall rating footnote'].fillna(df2['Hospital overall rating footnote'].mode()[0])
df2['Mortality national comparison footnote'] = df2['Mortality national comparison footnote'].fillna(df2['Mortality national comparison footnote'].mode()[0])
df2['Safety of care national comparison footnote'] = df2['Safety of care national comparison footnote'].fillna(df2['Safety of care national comparison footnote'].mode()[0])
df2.shape
# Out:
# (264385, 43)

# %%
#df2.fillna(df2.mean())

# %%
df2.isnull().sum()
# Out:
# Facility ID                                                           0
# Facility Name                                                         0
# Address                                                               0
# City                                                                  0
# State                                                                 0
# ZIP Code                                                              0
# County Name                                                           0
# Phone Number                                                          0
# HCAHPS Measure ID                                                     0
# HCAHPS Question                                                       0
# HCAHPS Answer Description                                             0
# Patient Survey Star Rating                                            0
# Patient Survey Star Rating Footnote                                   0
# ...

# %%
df2.to_csv('clean_df2-project.csv')

# %%
df2.shape
# Out:
# (264385, 43)

# %%
df2.head()
# Out:
#    Facility ID                     Facility Name                 Address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number     HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701         H_STAR_RATING
# 1  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_A_P
# 2  DOTHAN    AL     36301     HOUSTON    3347938701      H_CLEAN_HSP_SN_P
# 3  DOTHAN    AL     36301     HOUSTON    3347938701       H_CLEAN_HSP_U_P
# 4  DOTHAN    AL     36301     HOUSTON    3347938701  H_CLEAN_LINEAR_SCORE
#
#                                      HCAHPS Question  ...  \
# ...
